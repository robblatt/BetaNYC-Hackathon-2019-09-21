# %%
# (\__/)    Still a little messy, but this code was written for the Mobility for All Abilities
# (•ㅅ•)     on 9/21/2019 as part of the 'Reliable Access to Subways' team organized by
# / 　 づ    TransitCenter and United Equal Access NY.

# %%
import PyPDF2 
from tqdm import tqdm_notebook as tqdm
import re
import pandas

# %%
def convert_transit_pdf_to_csv(pdf, start, end):
    
    '''
    Input is a PDF file in the local directory, the first page
    of the PDF and the last page of the PDF. The function adjusts
    the first page to account for zero-based numbering. It will
    output a csv file back into the directory.
    
    There are a few issues with the code as-written. If an escalator
    or elevator is avialable 0.00% of the time, it will add an additional
    digit or character to the availability column. There is one other
    issue I've encountered where the subway lines aren't formatted properly.
    
    The comments will occaisonaly cut off and a fix for that is the first
    priority once this code is re-visited.
    '''

    page_range = list(range(start - 1,end))

    pdfFileObj = open(pdf, 'rb') 

    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

    lines = []
    availability = []
    units = []
    stations = []
    conditions = []

    condition = ''

    for page in page_range:
        pageObj = pdfReader.getPage(page) 
        current_page = pageObj.extractText().split('\n')

        for i in range(len(current_page[:-2])):
            
            # removes some titles that would otherwise be caught up in 
            if not re.match(string = current_page[i], pattern = '.* THAN 85% AVAILABILITY'):
                if len(current_page[i]) > 1:
                    if len(current_page[i]) > 40:
                        condition += current_page[i]
                    if re.match(string = current_page[i][-5:], pattern = '\d\.\d{2}\%'):
                        availability.append(current_page[i][-6:])
                        lines.append(current_page[i][:-6])
                    if re.match(string = current_page[i], pattern = 'E[LS]\d{3}'):
                        units.append(current_page[i])
                        stations.append(current_page[i + 1])
                        if len(condition) > 1:
                            conditions.append(condition)
                            condition = ''
                if i == len(current_page[:-2]) - 1:
                    conditions.append(condition)
                    condition = ''
    df_stations = pd.DataFrame(
        {'units': units,
         'stations': stations,
         'lines' : lines,
         'availability' : availability,
         'condition': conditions
        })

    df_stations.to_csv(pdf + ' converted.csv')

# %%
convert_transit_pdf_to_csv('180521_1030_Transit.pdf', 220, 222)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-419-40ec77ef3dab> in <module>
# ----> 1 convert_transit_pdf_to_csv('180521_1030_Transit.pdf', 220, 222)
#
# <ipython-input-411-9ead7453481a> in convert_transit_pdf_to_csv(pdf, start, end)
#      58          'lines' : lines,
#      59          'availability' : availability,
# ---> 60          'condition': conditions
#      61         })
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df_stations
# Out:
#     units                     stations  lines availability  \
# 0   EL120                      190 St       A       27.18%
# 1   EL249                       86 St       Q       84.06%
# 2   ES104                 Gun Hill Rd      25       83.76%
# 3   ES105                 Gun Hill Rd      25       83.48%
# 4   ES106  West Farms Sq-E Tremont Av      25       79.51%
# 5   ES108                Intervale Av      25       69.84%
# 6   ES114       161 St-Yankee Stadium       4       69.45%
# 7   ES120             Pelham Bay Park       6       22.72%
# 8   ES305                    Court St       R       50.95%
# 9   ES347           Broadway Junction   ACJLZ       84.90%
# 10  ES349                  Smith 9 St      FG       83.91%
# 11  ES101                      125 St       1       82.81%
# 12  ES102                      125 St       1       80.27%
# 13  ES118                      181 St       A       82.54%
# 14  ES208         Grand Central-42 St       7       84.73%
# 15  ES217              Times Sq-42 St       7       80.93%
# 16  ES233             34 St-Herald Sq    BDFM       79.90%
# 17  ES235             34 St-Herald Sq    BDFM       84.34%
# 18  ES255         Grand Central-42 St   4567S       82.56%
# 19  ES256         Grand Central-42 St   4567S       82.81%
# 20  ES297                       86 St       Q       83.29%
# 21  ES626          34 St-Hudson Yards       7       82.94%
# 22  ES632          34 St-Hudson Yards       7       78.11%
# 23  ES635          34 St-Hudson Yards       7       82.15%
# 24  ES451              74 St-Broadway       7       79.99%
# 25  ES455            Flushing-Main St       7       81.61%
# 26  ES456            Flushing-Main St       7       82.81%
#
#                                             condition
# 0   This elevator was out multiple times due to le...
# 1   This elevator was out of service from 11/19/18...
# 2   From 10/1/18 to 12/23/18 the escalator went ou...
# 3   From 10/1/18 to 12/23/18 the escalator went ou...
# 4   From 10/1/18 to 12/23/18 the escalator went ou...
# 5   The escalator was out service from 10/17/2018 ...
# 6   The escalator was out of service from 10/18/20...
# 7   The escalator was out of service from 09/01/20...
# 8   This escalator was out of service from 10/6/18...
# 9   This escalator was out of service 13 times due...
# 10  This escalator was out of service 12 times due...
# 11  The escalator was out of service from 10/04/20...
# 12  The escalator was out of service multiple time...
# 13  The escalator was out of service from 10/18/20...
# 14  The escalator went out of service multiple tim...
# 15  The escalator went out of service multiple tim...
# 16  The escalator went out multiple times for hand...
# 17  The escalator was out of service from 12/4/18 ...
# 18  This escalator was out of service from 11/30/1...
# 19  The escalator was out of service multiple time...
# 20  This escalator was out of service from 10/5/18...
# 21  This escalator was out of service from 10/12/1...
# 22  This escalator was out of service from 10/5/18...
# 23  This escalator was out of service from 11/24/1...
# 24  This escalator was out of service 6 times due ...
# 25  This escalator was out of service from 10/26/1...
# 26  This escalator was out of service 9 times due ...

# %%
len(conditions)
# Out:
# 27

# %%
len(lines)
# Out:
# 27

# %%
len(units)
# Out:
# 27

# %%
len(stations)
# Out:
# 27

# %%
len(availability)
# Out:
# 27

# %%
current_page
# Out:
# ['Borough/ Unit',
#  'Location',
#  '24 Hr ',
#  'Availability',
#  'Comments',
#  '4TH QUARTER 2018 ESCALATORS WITH LESS THAN 85% AVAILABILITY',
#  'ES235',
#  '34 St-Herald Sq ',
#  'BDFM84.34%',
#  'The escalator was out of service from 12/4/18 to 12/11/18 due to worn out handrail and countershaft chains ',
#  'as well as defective brake assemblies. The countershaft assembly and chain were replaced and adjusted. ',
#  'The right handrail chain was adjusted. The main brakes were replaced and adjusted as well as a controller ',
#  '',
#  'relay; the escalator was tested and returned to service. The escalator was out multiple times due to the ',
#  '',
#  'activation of various safety devices. Those safety devices were tested and adjusted as needed.',
#  'ES255',
#  'Grand Central-42 St ',
#  '4567S82.56%',
#  'This escalator was out of service from 11/30/18 to 12/3/18 due to an inspection of the proper operation of ',
#  'the up and down operation. The escalator was found to be operating as designed and returned to service. ',
#  'The escalator was out multiple times for the activation of the comb stop safety device. The comb stop safety ',
#  '',
#  'device was inspected and adjusted; the escalator was tested and returned to service. The escalator was out ',
#  'of service multiple times for the activation of the emergency stop button. A panhandler was observed ',
#  '',
#  'stopping the escalator on multiple occasions. The district police were informed, and the panhandler was ',
#  '',
#  'removed.  This escalator is scheduled for replacement in the 2015-2019 Capital Program.',
#  'ES256',
#  'Grand Central-42 St ',
#  '4567S82.81%',
#  'The escalator was out of service multiple times for a broken handrail safety device. The PLC was giving out ',
#  'erroneous messages indicating a broken handrail fault when there were no issues. The wiring was ',
#  '',
#  'corrected. The escalator was tested and returned to service. The escalator was out multiple times for the ',
#  '',
#  'brake failure. The brake pressure switch and brake wear monitors were inspected and repaired as needed. ',
#  '',
#  'The escalator was tested and returned to service. There were also multiple outages for emergency stop ',
#  '',
#  'button activation and comb stop safety device activation. Both devices were inspected and repaired as ',
#  'needed. ',
#  'ES297',
#  '86 St ',
#  'Q83.29%',
#  'This escalator was out of service from 10/5/18 to 10/17/18 due to a warranty repair on the safety brake. The ',
#  'safety brake failed. The safety brake was replaced and adjusted. The escalator was tested and returned to ',
#  'service.',
#  'ES626',
#  '34 St-Hudson Yards ',
#  '782.94%',
#  'This escalator was out of service from 10/12/18 to 10/17/18 due to a defective handrail. The left handrail ',
#  'was replaced and adjusted; the escalator was tested and returned to service. The escalator was out of ',
#  '',
#  'service from 10/22/18 to 10/24/18 due to the comb stop safety devices not operating correctly. The comb ',
#  '',
#  'stop safety devices were tested and adjusted; the escalator was tested and returned to service. The ',
#  '',
#  'escalator was out of service from 10/24/18 to 10/28/18 due to step index alignment at the comb segment ',
#  '',
#  'area. Worn step axles were replaced to correct step indexing. the escalator was tested and returned to ',
#  'service.',
#  'ES632',
#  '34 St-Hudson Yards ',
#  '778.11%',
#  'This escalator was out of service from 10/5/18 to 10/19/18. The flywheel and drive motor were not operating ',
#  'correctly. The contractor replaced the flywheel and drive motor; the escalator was tested and returned to ',
#  'service. The escalator was out multiple times due to the activation of the comb stop and comb impact safety ',
#  'devices. The comb stop and comb impact safety devices were inspected and tested; the escalator was ',
#  'tested and returned to service.',
#  'ES635',
#  '34 St-Hudson Yards ',
#  '782.15%',
#  'This escalator was out of service from 11/24/18 to 12/2/18 and on 12/7/18 for warranty repairs. The gear ',
#  'case seal was leaking. The gear case seal was replaced. The escalator was tested and returned to service. ',
#  '',
#  'This escalator was out multiple times for the activation of the comb stop and comb impact safety devices. ',
#  '',
#  'The comb stop and comb impact safety devices were inspected and tested; the escalator was tested and ',
#  'returned to service.',
#  'QUEENS',
#  'ES451',
#  '74 St-Broadway ',
#  '779.99%',
#  'This escalator was out of service 6 times due to various issues involving the controller (blown fuses), comb ',
#  'assembly and handrail inlet. This escalator was out of service an additional 2 times due to planned ',
#  '',
#  'repairs/adjustments. All of the issues have been resolved; the escalator was tested and returned to service. ',
#  'ES455',
#  'Flushing-Main St ',
#  '781.61%',
#  'This escalator was out of service from 10/26/18 to 11/4/18 due to water damage. Water flooded the lower ',
#  'pit damaging various components. Water damage put this escalator out of service again from 12/21/18 to ',
#  '12/23/18. Water was found in the controller causing it to malfunction. Repairs were made; the escalator was ',
#  'tested and returned to service. ',
#  '',
#  'This escalator was out of service 9 times due to various issues involving the comb assembly. Repairs has ',
#  'been completed and we will closely monitor the operation of this escalator in order to improve its availability ',
#  '',
#  'to our customers.',
#  'ES456',
#  'Flushing-Main St ',
#  '782.81%',
#  'This escalator was out of service 9 times due to various issues involving the comb assembly/brake fault. ',
#  'Repairs were made, and the controller was reset; the escalator was tested and returned to service. This ',
#  'escalator was out of service another 14 times due to vandalism as a result of customers activating either the ',
#  '',
#  'upper or lower emergency stop buttons.',
#  'Master Page # 330 of 377 - New York City Transit and Bus Committee Meeting 2/25/2019________________________________________________________________________________']

# %%
def convert_transit_pdf_to_csv2(pdf, start, end):
    
    '''
    Input is a PDF file in the local directory, the first page
    of the PDF and the last page of the PDF. The function adjusts
    the first page to account for zero-based numbering. It will
    output a csv file back into the directory.
    
    There are a few issues with the code as-written. If an escalator
    or elevator is avialable 0.00% of the time, it will add an additional
    digit or character to the availability column. There is one other
    issue I've encountered where the subway lines aren't formatted properly.
    
    The comments will occaisonaly cut off and a fix for that is the first
    priority once this code is re-visited.
    '''

    page_range = list(range(start - 1,end))

    pdfFileObj = open(pdf, 'rb') 

    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

    lines = []
    availability = []
    units = []
    stations = []
    conditions = []

    condition = ''

    for page in page_range:
        pageObj = pdfReader.getPage(page) 
        current_page = pageObj.extractText().split('\n')

        for i in range(len(current_page[:-2])):
            
            # removes some titles that would otherwise be caught up in 
            if not re.match(string = current_page[i], pattern = '.* THAN 85% AVAILABILITY'):
                if len(current_page[i]) > 1:
                    if len(current_page[i]) > 40:
                        condition += current_page[i]
                    if re.match(string = current_page[i][-5:], pattern = '\d\.\d{2}\%'):
                        availability.append(current_page[i][-6:])
                        lines.append(current_page[i][:-6])
                    if re.match(string = current_page[i], pattern = 'E[LS]\d{3}'):
                        units.append(current_page[i])
                        stations.append(current_page[i + 1])
                        if len(condition) > 1:
                            conditions.append(condition)
                            condition = ''
                if i == len(current_page[:-2]) - 1:
                    conditions.append(condition)
                    condition = ''
    df_stations = pd.DataFrame(
        {'units': units,
         'stations': stations,
         'lines' : lines,
         'availability' : availability,
         'condition': conditions
        })

    df_stations.to_csv(pdf + ' converted.csv')

# %% [markdown]
# # A Tabula Approach

# %%
from tabula import read_pdf
import tabula

# %%
df = tabula.read_pdf('190923_1000_Transit.pdf', pages=[380, 381, 382, 383, 384])
df.dropna(how = 'all', inplace = True)
df.reset_index(inplace = True, drop = True)

# %%
df.head(4)
# Out:
#   2ND QUARTER 2019 ELEVATORS WITH LESS THAN 85% AVAILABILITY  \
# 0                                      Borough/ Unit
# 1                                           BROOKLYN
# 2                                              EL204
# 3                                              EL119
#
#                   Unnamed: 1           Unnamed: 2  \
# 0                   Location  24 Hr\rAvailability
# 1                        NaN                  NaN
# 2  Grand Central-42 St 4567S               72.36%
# 3                   181 St A               81.16%
#
#                                           Unnamed: 3
# 0                                           Comments
# 1                                                NaN
# 2  This elevator was out of service on multiple d...
# 3  This elevator was out of service from 6/3/19 t...

# %%
# drops completely empty rows 

for i in range(len(df)):
#     drops header rows
#     if i in list(df[(df[df.columns[-1]] == 'Comments')].index):
#         df.drop(df.index[[i]], inplace = True)
#     identifies subway lines
    try:
        if math.isnan(float(df.iloc[i][1])) is True:
            pass
    except:
        if df.iloc[i][1] != 'Location':
            print(str(i) + ' Unit: ' + df.iloc[i][0] + ' Station: ' + ' '.join(df.iloc[i][1].split(' ')[:-1]) + '. Line: ' + df.iloc[i][1].split(' ')[-1])
# Out:
# 2 Unit: EL204 Station: Grand Central-42 St. Line: 4567S
# 3 Unit: EL119 Station: 181 St. Line: A
# 4 Unit: EL224 Station: 8 Av. Line: L
# 9 Unit: ES104 Station: Gun Hill Rd. Line: 25
# 13 Unit: ES105 Station: Gun Hill Rd. Line: 25
# 18 Unit: ES106 Station: West Farms Sq-E Tremont Av. Line: 25
# 24 Unit: ES108 Station: Intervale Av. Line: 25
# 28 Unit: ES112 Station: Norwood-205 St. Line: D
# 32 Unit: ES113 Station: 161 St-Yankee Stadium. Line: 4
# 37 Unit: ES114 Station: 161 St-Yankee Stadium. Line: 4
# 43 Unit: ES121 Station: Pelham Bay Park. Line: 6
# 49 Unit: ES122 Station: Pelham Pkwy. Line: 25
# 56 Unit: ES123 Station: Pelham Pkwy. Line: 25
# 64 Unit: ES306 Station: Court St. Line: R
# 70 Unit: ES308 Station: DeKalb Av. Line: BQR
# 72 Unit: ES310 Station: Atlantic Av. Line: BQ
# 75 Unit: ES320 Station: Jay St. Line: ACF
# 78 Unit: ES321 Station: High St. Line: AC
# 82 Unit: ES332 Station: Myrtle-Wyckoff Avs. Line: LM
# 87 Unit: ES333 Station: Myrtle-Wyckoff Avs. Line: LM
# 93 Unit: ES335 Station: West 8 St-NY Aquarium. Line: FQ
# 94 Unit: ES346 Station: Brighton Beach. Line: BQ
# 95 Unit: ES349 Station: Smith 9 St. Line: FG
# 97 Unit: ES101 Station: 125 St. Line: 1
# 98 Unit: ES102 Station: 125 St. Line: 1
# 99 Unit: ES115 Station: 145 St. Line: BD
# 100 Unit: ES116 Station: 145 St. Line: BD
# 101 Unit: ES117 Station: 181 St. Line: A
# 102 Unit: ES209 Station: Grand Central-42 St. Line: 7
# 103 Unit: ES210 Station: Grand Central-42 St. Line: 7
# 104 Unit: ES211 Station: 59 St. Line: 456
# 105 Unit: ES215 Station: Lexington Av-59 St. Line: NQRW
# 106 Unit: ES217 Station: Times Sq-42 St. Line: 7
# 107 Unit: ES218 Station: Times Sq-42 St. Line: 7
# 108 Unit: ES229 Station: 34 St-Herald Sq. Line: BDFM
# 109 Unit: ES231 Station: 34 St-Herald Sq. Line: BDFM
# 112 Unit: ES232 Station: 34 St-Herald Sq. Line: BDFM
# 113 Unit: ES236 Station: 34 St-Herald Sq. Line: BDFM
# 114 Unit: ES242 Station: 5 Av-53 St. Line: EM
# 115 Unit: ES246 Station: Lexington Av-53 St. Line: EM
# 116 Unit: ES249 Station: Lexington Av-59 St. Line: NRW
# 117 Unit: ES256 Station: Grand Central-42 St. Line: 4567S
# 118 Unit: ES269 Station: Lexington Av-53 St. Line: EM
# 119 Unit: ES285 Station: 72 St. Line: Q
# 120 Unit: ES295 Station: 72 St. Line: Q
# 121 Unit: ES327 Station: Delancey St. Line: F
# 122 Unit: ES351 Station: Whitehall St. Line: RW
# 123 Unit: ES364 Station: Fulton St. Line: 45
# 124 Unit: ES403 Station: Lexington Av-63 St. Line: FQ
# 125 Unit: ES411 Station: Roosevelt Island. Line: F
# 126 Unit: ES413 Station: Roosevelt Island. Line: F
# 127 Unit: ES622 Station: 34 St-Hudson Yards. Line: 7
# 128 Unit: ES623 Station: 34 St-Hudson Yards. Line: 7
# 129 Unit: ES628 Station: 34 St-Hudson Yards. Line: 7
# 131 Unit: ES437 Station: Sutphin Blvd-Archer Av-JFK. Line: EJZ
# 132 Unit: ES439 Station: Jamaica Center. Line: EJZ
# 135 Unit: ES448 Station: Woodside-61 St. Line: 7
# 136 Unit: ES449 Station: 74 St-Broadway. Line: 7
# 137 Unit: ES450 Station: 74 St-Broadway. Line: 7
# 138 Unit: ES455 Station: Flushing-Main St. Line: 7
# 139 Unit: ES456 Station: Flushing-Main St. Line: 7
# 140 Unit: ES457 Station: Flushing-Main St. Line: 7

# %%
type(df.iloc[1][1])
# Out:
# float

# %%
df
# Out:
#     2ND QUARTER 2019 ELEVATORS WITH LESS THAN 85% AVAILABILITY  \
# 2                                             BROOKLYN
# 3                                                EL204
# 4                                                EL119
# 5                                                EL224
# 6                                                  NaN
# 7                                        Borough/ Unit
# 8                                                  NaN
# 9                                                BRONX
# 10                                               ES104
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                               ES105
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                               ES106
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                               ES108
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                               ES112
# 30                                                 NaN
# 31                                                 NaN
# ..                                                 ...
# 112                                              ES231
# 113  2ND QUARTER 2019 ESCALATORS WITH LESS THAN 85%...
# 114                                      Borough/ Unit
# 116                                              ES232
# 117                                              ES236
# 118                                              ES242
# 119                                              ES246
# 120                                              ES249
# 122                                              ES269
# 124                                              ES295
# 125                                              ES327
# 126                                              ES351
# 127                                              ES364
# 128                                              ES403
# 129                                              ES411
# 130                                              ES413
# 131                                              ES622
# 132                                              ES623
# 133                                              ES628
# 135                                             QUEENS
# 136                                              ES437
# 137                                              ES439
# 138  2ND QUARTER 2019 ESCALATORS WITH LESS THAN 85%...
# 139                                      Borough/ Unit
# 141                                              ES448
# 142                                              ES449
# 143                                              ES450
# 144                                              ES455
# 145                                              ES456
# 146                                              ES457
#
#                          Unnamed: 1           Unnamed: 2  \
# 2                               NaN                  NaN
# 3         Grand Central-42 St 4567S               72.36%
# 4                          181 St A               81.16%
# 5                            8 Av L               83.42%
# 6                               NaN                  NaN
# 7                               NaN             Location
# 8                               NaN                  NaN
# 9                               NaN                  NaN
# 10                   Gun Hill Rd 25                  NaN
# 11                              NaN                  NaN
# 12                              NaN                  NaN
# 13                              NaN                  NaN
# 14                   Gun Hill Rd 25                  NaN
# 15                              NaN                  NaN
# 16                              NaN                  NaN
# 17                              NaN                  NaN
# 18                              NaN                  NaN
# 19    West Farms Sq-E Tremont Av 25                  NaN
# 20                              NaN                  NaN
# 21                              NaN                  NaN
# 22                              NaN                  NaN
# 23                              NaN                  NaN
# 24                              NaN                  NaN
# 25                  Intervale Av 25                  NaN
# 26                              NaN                  NaN
# 27                              NaN                  NaN
# 28                              NaN                  NaN
# 29                 Norwood-205 St D                  NaN
# 30                              NaN                  NaN
# 31                              NaN                  NaN
# ..                              ...                  ...
# 112            34 St-Herald Sq BDFM               82.26%
# 113                             NaN                  NaN
# 114                        Location  24 Hr\rAvailability
# 116            34 St-Herald Sq BDFM               77.19%
# 117            34 St-Herald Sq BDFM               69.47%
# 118                   5 Av-53 St EM               83.33%
# 119           Lexington Av-53 St EM               79.00%
# 120          Lexington Av-59 St NRW               81.31%
# 122           Lexington Av-53 St EM               84.75%
# 124                         72 St Q               81.02%
# 125                   Delancey St F               77.26%
# 126                 Whitehall St RW               81.51%
# 127                    Fulton St 45               81.95%
# 128           Lexington Av-63 St FQ               84.64%
# 129              Roosevelt Island F               78.63%
# 130              Roosevelt Island F               35.72%
# 131            34 St-Hudson Yards 7               68.64%
# 132            34 St-Hudson Yards 7               83.18%
# 133            34 St-Hudson Yards 7               74.12%
# 135                             NaN                  NaN
# 136  Sutphin Blvd-Archer Av-JFK EJZ               81.65%
# 137              Jamaica Center EJZ               54.14%
# 138                             NaN                  NaN
# 139                        Location  24 Hr\rAvailability
# 141                Woodside-61 St 7               60.91%
# 142                74 St-Broadway 7               82.51%
# 143                74 St-Broadway 7               82.55%
# 144              Flushing-Main St 7               79.72%
# 145              Flushing-Main St 7               57.43%
# 146              Flushing-Main St 7               19.92%
#
#                                             Unnamed: 3
# 2                                                  NaN
# 3    This elevator was out of service on multiple d...
# 4    This elevator was out of service from 6/3/19 t...
# 5    This elevator was out of service on multiple o...
# 6    2ND QUARTER 2019 ESCALATORS WITH LESS THAN 85%...
# 7                                       24 Hr Comments
# 8                                         Availability
# 9                                                  NaN
# 10   74.40% This escalator had multiple outages for...
# 11   device activations. The escalator was out of s...
# 12   correct repeated outages for the lower combsto...
# 13   were adjusted; the escalator was tested and re...
# 14   79.55% This escalator was out of service multi...
# 15   upper and lower emergency stop buttons were ac...
# 16   combstop safety devices were activated. Each t...
# 17   service. Further work is required to inspect, ...
# 18   combstop safety devices in order to improve es...
# 19   68.09% This escalator was out of service multi...
# 20   activated.  The escalator was out of service f...
# 21   safety check and related work was completed; t...
# 22   escalator was out of service from 5/25/19 to 5...
# 23   members. The step chain tension device and swi...
# 24                                         to service.
# 25   34.94% This escalator was out of service from ...
# 26   tracks were repaired and adjusted, step bushin...
# 27   chain was shortened, combstop and comb impact ...
# 28                 was tested and returned to service.
# 29   66.57% This escalator was out of service from ...
# 30   carrier was sent to a vendor for repairs. The ...
# 31   guides were replaced and adjusted, top and bot...
# ..                                                 ...
# 112  This escalator was out of service from 4/7/19 ...
# 113                                                NaN
# 114                                           Comments
# 116  This escalator was out of service from 4/10/19...
# 117  This escalator was out of service from 4/1/19 ...
# 118  This escalator was out of service from 5/25/19...
# 119  This escalator was out of service from 4/30/19...
# 120  This escalator has had excessive outages due t...
# 122  This escalator was removed from service betwee...
# 124  This escalator was out of service between 4/11...
# 125  This escalator was out of service from 4/19/19...
# 126  This escalator was out of service from 5/10/19...
# 127  This escalator was out of service from 4/16/19...
# 128  This escalator was out of service from 5/6/19 ...
# 129  This escalator was out of service from 4/20/19...
# 130  The escalator is currently out of service from...
# 131  The escalator was out of service from 4/15/19 ...
# 132  The escalator was out of service numerous time...
# 133  The escalator was out of service from 4/15/19 ...
# 135                                                NaN
# 136  This escalator was out of service from 5/4/19 ...
# 137  The escalator was out of service from 5/7/19 t...
# 138                                                NaN
# 139                                           Comments
# 141  This escalator was out of service from 4/19/19...
# 142  This escalator was out of service from 4/15/19...
# 143  The escalator was out of service from 3/8/19 t...
# 144  This escalator was out of service from 4/13/19...
# 145  The escalator was out of service from 2/20/19 ...
# 146  The escalator was out of service from 4/22/19 ...
#
# [135 rows x 4 columns]

# %%
for range(len(df)):
    if
# Out:
# nan

# %%
import math

# %%
math.isnan(float(df.iloc[0][1]))
# Out:
# True

# %%
for i in range(len(df)):
# Out:
# 4567S
# A
# L
# 25
# 25
# 25
# 25
# D
# 4
# 4
# 6
# 25
# 25
# R
# BQR
# BQ
# ACF
# AC
# LM
# LM
# BQ
# 1
# 1
# BD
# BD
# A
# 7
# 7
# 456
# NQRW
# 7
# 7
# BDFM
# BDFM
# BDFM
# BDFM
# EM
# EM
# NRW
# EM
# Q
# Q
# F
# RW
# 45
# FQ
# F
# F
# 7
# 7
# 7
# EJZ
# EJZ
# 7
# 7
# 7
# 7
# 7
# 7

# %%
str(df.iloc[i][1]).split(' ')[-1]
# Out:
# 'nan'

# %%
df.iloc[i][1].split(' ')[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-ef1a83ba39fb> in <module>
# ----> 1 df.iloc[i][1].split(' ')[-1]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# Out:
# no

# %%
# Out:
# 4
