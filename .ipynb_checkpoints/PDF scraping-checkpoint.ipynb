# %%
import PyPDF2 
from tqdm import tqdm_notebook as tqdm
import re
import pandas

# %%
pdf = '190520_1030_Transit.pdf'

# %%
page_range = list(range(235,238))

# %%
pdfFileObj = open(pdf, 'rb')

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
lines = []
availability = []
units = []
stations = []
conditions = []

condition = ''

for page in page_range:
    pageObj = pdfReader.getPage(page) 
    current_page = pageObj.extractText().split('\n')

    for i in range(len(current_page[:-2])):
        if not re.match(string = current_page[i], pattern = '.* THAN 85% AVAILABILITY'):
            if len(current_page[i]) > 1:
                if len(current_page[i]) > 40:
                    condition += current_page[i]
                if re.match(string = current_page[i][-5:], pattern = '\d\.\d{2}\%'):
                    availability.append(current_page[i][-6:])
                    lines.append(current_page[i][:-6])
                if re.match(string = current_page[i], pattern = 'E[LS]\d{3}'):
                    units.append(current_page[i])
                    stations.append(current_page[i + 1])
                    if len(condition) > 1:
                        conditions.append(condition)
                        condition = ''
            if i == len(current_page[:-2]) - 1:
                conditions.append(condition)
                condition = ''
df_stations = pd.DataFrame(
    {'units': units,
     'stations': stations,
     'lines' : lines,
     'availability' : availability,
     'condition': conditions
    })

# %%
df_stations
# Out:
#     units                     stations     lines availability  \
# 0   ES104                 Gun Hill Rd         25       82.89%
# 1   ES106  West Farms Sq-E Tremont Av         25       77.55%
# 2   ES108                Intervale Av         25       78.18%
# 3   ES111                 Parkchester          6       79.77%
# 4   ES113       161 St-Yankee Stadium          4       82.23%
# 5   ES114       161 St-Yankee Stadium          4       60.20%
# 6   ES120             Pelham Bay Park          6       68.77%
# 7   ES122                 Pelham Pkwy         25       82.74%
# 8   ES123                 Pelham Pkwy         25       76.73%
# 9   ES304                President St         25       77.44%
# 10  ES309                   DeKalb Av        BQR       83.99%
# 11  ES315                  Smith 9 St         FG       75.73%
# 12  ES321                     High St         AC       62.65%
# 13  ES324                     High St         AC       77.09%
# 14  ES333          Myrtle-Wyckoff Avs         LM       81.62%
# 15  ES335       West 8 St-NY Aquarium         FQ       80.96%
# 16  ES346              Brighton Beach         BQ       45.58%
# 17  ES349                  Smith 9 St         FG       64.43%
# 18  ES101                      125 St          1       76.29%
# 19  ES102                      125 St          1       73.31%
# 20  ES103                      125 St          1       74.45%
# 21  ES119                      181 St          A       79.43%
# 22  ES208         Grand Central-42 St          7       83.90%
# 23  ES209         Grand Central-42 St          7       82.19%
# 24  ES211                       59 St        456       76.40%
# 25  ES217              Times Sq-42 St          7       78.74%
# 26  ES221             34 St-Herald Sq   BDFMNQRW       81.31%
# 27  ES229             34 St-Herald Sq       BDFM       82.19%
# 28  ES231             34 St-Herald Sq       BDFM       82.74%
# 29  ES232             34 St-Herald Sq       BDFM       84.42%
# 30  ES233             34 St-Herald Sq       BDFM       81.43%
# 31  ES241                  5 Av-53 St         EM       47.47%
# 32  ES249          Lexington Av-59 St        NRW       81.63%
# 33  ES255         Grand Central-42 St      4567S       80.09%
# 34  ES256         Grand Central-42 St      4567S       82.89%
# 35  ES295                       72 St          Q       70.37%
# 36  ES411            Roosevelt Island          F       83.83%
# 37  ES448              Woodside-61 St          7       79.92%
# 38  ES450              74 St-Broadway          7       63.20%
# 39  ES455            Flushing-Main St          7       82.57%
# 40  ES456            Flushing-Main St          7       45.46%
# 41  ES457            Flushing-Main St          7       80.87%
#
#                                             condition
# 0   This escalator was out of service from 1/7/19 ...
# 1   This escalator was out of service from 12/28/1...
# 2   This escalator was out of service from 12/29/1...
# 3   This escalator was out of service from 1/21/19...
# 4   This escalator was out of service from 1/10/09...
# 5   This escalator was out of service from 1/20/19...
# 6   This escalator was out of service from 1/25/19...
# 7   This escalator was out of service from 1/12/19...
# 8   This escalator was out of service 3/6/19 to 3/...
# 9   This escalator was out of service 20 times due...
# 10  This escalator was out of service 46 times due...
# 11  This escalator was out of service 15 times due...
# 12  This escalator was out of service 11 times due...
# 13  This escalator was out of service 11 times due...
# 14  This escalator was out of service 33 times due...
# 15  This escalator was out of service 18 times due...
# 16  This escalator was out of service 9 times due ...
# 17  This escalator was out of service 7 times due ...
# 18  This escalator has experienced numerous outage...
# 19  This escalator experienced numerous outages fo...
# 20  This escalator was out of service from 1/31/19...
# 21  This escalator was out of service from 3/4/19 ...
# 22  This escalator was out of service from 1/12/19...
# 23  This escalator was out of service form 1/3/19 ...
# 24  This escalator was out of service from 1/10/19...
# 25  This escalator was out of service numerous tim...
# 26  This escalator was out of service numerous tim...
# 27  This escalator was out of service from 3/3/19 ...
# 28  This escalator was out of service from 2/16/19...
# 29  This escalator was out of service from 3/9/19 ...
# 30  This escalator was out of service from 3/9/19 ...
# 31  This escalator was out of service between 1/4/...
# 32  This escalator had repeated outages for the ac...
# 33  This escalator was out of service from 1/8/19 ...
# 34  This escalator was out of service from 2/8/19 ...
# 35  This escalator was out of service from 12/30/1...
# 36  This escalator was out of service 24 times due...
# 37  This escalator was out of service from 1/11/19...
# 38  This escalator was out of service 14 times due...
# 39  This escalator was out of service 21 times due...
# 40  This escalator was out of service 6 times due ...
# 41  This escalator was out of service 12 times due...

# %%
df_stations.to_csv(pdf + ' converted.csv')
