# %%
from tabula import read_pdf
import tabula
import pandas as pd
import re
import math
import warnings
import PyPDF2
from tqdm import tqdm_notebook as tqdm
warnings.filterwarnings(action='always')

pd.options.display.max_rows = 4000

# %%
def page_transform(page, pdf):
    
    df = tabula.read_pdf(pdf, pages=page)

    df_revision = df.copy()
    df_null = df.isna()

    df_revision.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=[" "," "], regex=True, inplace=True)

    unit = []
    station = []
    line = []
    availability = []
    comment = ''
    comments = []

    if len(df.columns) == 3:

        df_comment = pd.DataFrame(
            {'full comment': df[df.columns[2]].str.contains('^(Th).*$'),
             'starts percent': df[df.columns[2]].str.contains('\d{1,2}\.\d{2}\%'),
             'continued comment': df[df.columns[2]].str.contains('^[a-zA-SU-Z]*[\s]'),
             'all caps': df[df.columns[2]].str.contains('^[^a-z]*$'),
             'no spaces': df[df.columns[2]].str.contains('^[^\s]*$'),
            })

        for i in range(len(df)):
            if re.match(string = str(df[df.columns[0]][i]), pattern = 'E[SL]\d{3}'):
                unit.append(df[df.columns[0]][i])
            if re.match(string = str(df[df.columns[1]][i]).split(' ')[-1], pattern = '[ABCDEFGJLMNRQWZ1-7]'):
                line.append(df[df.columns[1]][i].split(' ')[-1])
                station.append(' '.join(df[df.columns[1]][i].split(' ')[:-1]))
            if re.match(string = str(df[df.columns[2]][i]).split(' ')[0], pattern = '\d{1,2}\.\d{2}\%'):
                availability.append(df[df.columns[2]][i].split(' ')[0])
            if df_comment['starts percent'][i] == True:
                if len(comment) > 0:
                    comments.append(comment)
                    comment = ''
                comment += ' '.join(df_revision[df_revision.columns[2]][i].split(' ')[1:])

            if df_comment['full comment'][i] == True and df_null[df_revision.columns[1]][i] == True:
                comment += df_revision[df_revision.columns[2]][i]

            if df_comment['full comment'][i] == True and df_null[df_revision.columns[1]][i] == False:
                if len(comment) > 0:
                    comments.append(comment)
                    comment = ''
                comments.append(df_revision[df_revision.columns[2]][i])

            if df_comment['continued comment'][i] == True and i != 0:
                comment += df_revision[df_revision.columns[2]][i]

        if len(comment) > 0:
            comments.append(comment)        

        df_output = pd.DataFrame(
            {'unit': unit,
             'station': station,
             'line': line,
             'availability': availability,
             'comments' : comments
            })

    if len(df.columns) > 4:
        df = df[list(df.columns[:-1])]

    if len(df.columns) == 4:

        df_comment = pd.DataFrame(
            {'full comment': df[df.columns[3]].str.contains('^(Th).*$'),
             'starts percent': df[df.columns[3]].str.contains('\d{1,2}\.\d{2}\%'),
             'continued comment': df[df.columns[3]].str.contains('^[a-zA-SU-Z]*[\s]'),
             'all caps': df[df.columns[3]].str.contains('^[^a-z]*$'),
             'no spaces': df[df.columns[3]].str.contains('^[^\s]*$'),
            })

        for i in range(len(df)):
            if df.iloc[i][1] != 'Location':
                if re.match(string = str(df.iloc[i][0]), pattern = 'E|[SL]\d{3}'):
                    unit.append(df.iloc[i][0])
                if str(df.iloc[i][1]) != 'nan':
                    station.append(' '.join(str(df.iloc[i][1]).split(' ')[:-1]))
                if re.match(string = str(df.iloc[i][1]).split(' ')[-1], pattern = '[ABCDEFGJLMNRQWZ1-7]'):
                    line.append(str(df.iloc[i][1]).split(' ')[-1])

            if df.iloc[i].isna().sum() == 0:
                if re.match(string = df.iloc[i][2], pattern = '\d{1,2}\.\d{2}\%'):
                    availability.append(df.iloc[i][2])

            if df.iloc[i].isna().sum() == 1:
                if re.match(string = df.iloc[i][3].split(' ')[0], pattern = '\d{1,2}\.\d{2}\%'):
                    availability.append(df.iloc[i][3].split(' ')[0])

            if df_comment['starts percent'][i] == True:
                if len(comment) > 0:
                    comments.append(comment)
                    comment = ''
                comment += ' '.join(df_revision[df_revision.columns[3]][i].split(' ')[1:])

            if df_comment['full comment'][i] == True and df_null[df_null.columns[2]][i] == True:
                comment += df_revision[df_revision.columns[3]][i]

            if df_comment['full comment'][i] == True and df_null[df_null.columns[2]][i] == False:
                if len(comment) > 0:
                    comments.append(comment)
                    comment = ''
                comments.append(df_revision[df_revision.columns[3]][i])

            if df_comment['continued comment'][i] == True:
                comment += df_revision[df_revision.columns[3]][i]

        if len(comment) > 0:
            comments.append(comment)        


        df_output = pd.DataFrame(
            {'unit': unit,
             'station': station,
             'line': line,
             'availability': availability,
             'comments' : comments
            })
        
    return df_output
# Out:
# <>:21: DeprecationWarning: invalid escape sequence \d
# <>:22: DeprecationWarning: invalid escape sequence \s
# <>:24: DeprecationWarning: invalid escape sequence \s
# <>:28: DeprecationWarning: invalid escape sequence \d
# <>:33: DeprecationWarning: invalid escape sequence \d
# <>:71: DeprecationWarning: invalid escape sequence \d
# <>:72: DeprecationWarning: invalid escape sequence \s
# <>:74: DeprecationWarning: invalid escape sequence \s
# <>:79: DeprecationWarning: invalid escape sequence \d
# <>:87: DeprecationWarning: invalid escape sequence \d
# <>:91: DeprecationWarning: invalid escape sequence \d
# <>:21: DeprecationWarning: invalid escape sequence \d
# <>:22: DeprecationWarning: invalid escape sequence \s
# <>:24: DeprecationWarning: invalid escape sequence \s
# <>:28: DeprecationWarning: invalid escape sequence \d
# <>:33: DeprecationWarning: invalid escape sequence \d
# <>:71: DeprecationWarning: invalid escape sequence \d
# <>:72: DeprecationWarning: invalid escape sequence \s
# <>:74: DeprecationWarning: invalid escape sequence \s
# <>:79: DeprecationWarning: invalid escape sequence \d
# <>:87: DeprecationWarning: invalid escape sequence \d
# <>:91: DeprecationWarning: invalid escape sequence \d
# <>:21: DeprecationWarning: invalid escape sequence \d
# <>:22: DeprecationWarning: invalid escape sequence \s
# <>:24: DeprecationWarning: invalid escape sequence \s
# <>:28: DeprecationWarning: invalid escape sequence \d
# <>:33: DeprecationWarning: invalid escape sequence \d
# <>:71: DeprecationWarning: invalid escape sequence \d
# <>:72: DeprecationWarning: invalid escape sequence \s
# <>:74: DeprecationWarning: invalid escape sequence \s
# <>:79: DeprecationWarning: invalid escape sequence \d
# <>:87: DeprecationWarning: invalid escape sequence \d
# <>:91: DeprecationWarning: invalid escape sequence \d
# <ipython-input-3-eeb1620e0206>:21: DeprecationWarning: invalid escape sequence \d
#   'starts percent': df[df.columns[2]].str.contains('\d{1,2}\.\d{2}\%'),
# <ipython-input-3-eeb1620e0206>:22: DeprecationWarning: invalid escape sequence \s
#   'continued comment': df[df.columns[2]].str.contains('^[a-zA-SU-Z]*[\s]'),
# <ipython-input-3-eeb1620e0206>:24: DeprecationWarning: invalid escape sequence \s
#   'no spaces': df[df.columns[2]].str.contains('^[^\s]*$'),
# <ipython-input-3-eeb1620e0206>:28: DeprecationWarning: invalid escape sequence \d
#   if re.match(string = str(df[df.columns[0]][i]), pattern = 'E[SL]\d{3}'):
# <ipython-input-3-eeb1620e0206>:33: DeprecationWarning: invalid escape sequence \d
#   if re.match(string = str(df[df.columns[2]][i]).split(' ')[0], pattern = '\d{1,2}\.\d{2}\%'):
# <ipython-input-3-eeb1620e0206>:71: DeprecationWarning: invalid escape sequence \d
#   'starts percent': df[df.columns[3]].str.contains('\d{1,2}\.\d{2}\%'),
# <ipython-input-3-eeb1620e0206>:72: DeprecationWarning: invalid escape sequence \s
#   'continued comment': df[df.columns[3]].str.contains('^[a-zA-SU-Z]*[\s]'),
# <ipython-input-3-eeb1620e0206>:74: DeprecationWarning: invalid escape sequence \s
#   'no spaces': df[df.columns[3]].str.contains('^[^\s]*$'),
# <ipython-input-3-eeb1620e0206>:79: DeprecationWarning: invalid escape sequence \d
#   if re.match(string = str(df.iloc[i][0]), pattern = 'E|[SL]\d{3}'):
# <ipython-input-3-eeb1620e0206>:87: DeprecationWarning: invalid escape sequence \d
#   if re.match(string = df.iloc[i][2], pattern = '\d{1,2}\.\d{2}\%'):
# <ipython-input-3-eeb1620e0206>:91: DeprecationWarning: invalid escape sequence \d
#   if re.match(string = df.iloc[i][3].split(' ')[0], pattern = '\d{1,2}\.\d{2}\%'):

# %%
page_transform(305, '170925_1030_Transit.pdf')
# Out:
# /Users/robblatt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:70: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#     unit              station line availability  \
# 0  EL107               181 St    1       41.95%
# 1  EL104               191 St    1       63.03%
# 2  EL120               190 St    A       72.86%
# 3  EL244  Grand Central‐42 St    7       75.71%
# 4  EL117               181 St    A       78.12%
# 5  EL118               181 St    A       78.54%
#
#                                             comments
# 0  This elevator was out of service from 4/28/17t...
# 1  This elevator was out of service from 4/28/17 ...
# 2  This elevator had several outages due to the e...
# 3  This elevator was out of service from 5/27/17 ...
# 4  This elevator was out of service on multiple o...
# 5  This elevator was out of service from 5/4/17 t...

# %%
page_transform(306, '170925_1030_Transit.pdf')
# Out:
# /Users/robblatt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:70: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#     unit                station   line availability  \
# 0  EL279  59 St‐Columbus Circle  ABCD1       84.30%
#
#                                             comments
# 0  This elevator was out of service from 6/16/17 ...

# %%
page_transform(307, '170925_1030_Transit.pdf')
# Out:
# /Users/robblatt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-cd3152b54486> in <module>
# ----> 1 page_transform(307, '170925_1030_Transit.pdf')
#
# <ipython-input-3-eeb1620e0206> in page_transform(page, pdf)
#      59              'line': line,
#      60              'availability': availability,
# ---> 61              'comments' : comments
#      62             })
#      63
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
pdf = '171113_1030_Transit.pdf'

# %%
page = 162

# %%
df = tabula.read_pdf(pdf, pages=page)

df_revision = df.copy()
df_null = df.isna()

df_revision.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=[" "," "], regex=True, inplace=True)

unit = []
station = []
line = []
availability = []
comment = ''
comments = []

if len(df.columns) == 3:

    df_comment = pd.DataFrame(
        {'full comment': df[df.columns[2]].str.contains(r'^(Th).*$'),
         'starts percent': df[df.columns[2]].str.contains(r'\d{1,2}\.\d{2}\%'),
         'continued comment': df[df.columns[2]].str.contains(r'^[a-zA-SU-Z]*[\s]'),
         'all caps': df[df.columns[2]].str.contains(r'^[^a-z]*$'),
         'no spaces': df[df.columns[2]].str.contains(r'^[^\s]*$'),
        })

    for i in range(len(df)):
        if re.match(string = str(df[df.columns[0]][i]), pattern = r'E[SL]\d{3}'):
            unit.append(df[df.columns[0]][i])
        if re.match(string = str(df[df.columns[1]][i]).split(' ')[-1], pattern = r'[ABCDEFGJLMNRQWZ1-7]'):
            if re.match(string = str(df[df.columns[1]][i]).split(' ')[-1], pattern = r'^((?!Location).)*$'):
                line.append(df[df.columns[1]][i].split(' ')[-1])
            if ' '.join(df[df.columns[1]][i].split(' ')[:-1]) is not '':
                station.append(' '.join(df[df.columns[1]][i].split(' ')[:-1]))
        if re.match(string = str(df[df.columns[2]][i]).split(' ')[0], pattern = r'\d{1,2}\.\d{2}\%'):
            availability.append(df[df.columns[2]][i].split(' ')[0])
        if df_comment['starts percent'][i] == True:
            if len(comment) > 0:
                comments.append(comment)
                comment = ''
            comment += ' '.join(df_revision[df_revision.columns[2]][i].split(' ')[1:])

        if df_comment['full comment'][i] == True and df_null[df_revision.columns[1]][i] == True:
            comment += df_revision[df_revision.columns[2]][i]

        if df_comment['full comment'][i] == True and df_null[df_revision.columns[1]][i] == False:
            if len(comment) > 0:
                comments.append(comment)
                comment = ''
            comments.append(df_revision[df_revision.columns[2]][i])

        if df_comment['continued comment'][i] == True and i != 0:
            comment += df_revision[df_revision.columns[2]][i]

    if len(comment) > 0:
        comments.append(comment)        

    df_output = pd.DataFrame(
        {'unit': unit,
         'station': station,
         'line': line,
         'availability': availability,
         'comments' : comments
        })

if len(df.columns) > 4:
    df = df[list(df.columns[:-1])]

if len(df.columns) == 4:

    df_comment = pd.DataFrame(
        {'full comment': df[df.columns[3]].str.contains(r'^(Th).*$'),
         'starts percent': df[df.columns[3]].str.contains(r'\d{1,2}\.\d{2}\%'),
         'continued comment': df[df.columns[3]].str.contains(r'^[a-zA-SU-Z]*[\s]'),
         'all caps': df[df.columns[3]].str.contains(r'^[^a-z]*$'),
         'no spaces': df[df.columns[3]].str.contains(r'^[^\s]*$'),
        })

    for i in range(len(df)):
        if df.iloc[i][1] != 'Location':
            if re.match(string = str(df.iloc[i][0]), pattern = r'E|[SL]\d{3}'):
                unit.append(df.iloc[i][0])
            if str(df.iloc[i][1]) != 'nan':
                station.append(' '.join(str(df.iloc[i][1]).split(' ')[:-1]))
            if re.match(string = str(df.iloc[i][1]).split(' ')[-1], pattern = r'[ABCDEFGJLMNRQWZ1-7]'):
                line.append(str(df.iloc[i][1]).split(' ')[-1])

        if df.iloc[i].isna().sum() == 0:
            if re.match(string = df.iloc[i][2], pattern = r'\d{1,2}\.\d{2}\%'):
                availability.append(df.iloc[i][2])

        if df.iloc[i].isna().sum() == 1:
            if re.match(string = df.iloc[i][3].split(' ')[0], pattern = r'\d{1,2}\.\d{2}\%'):
                availability.append(df.iloc[i][3].split(' ')[0])

        if df_comment['starts percent'][i] == True:
            if len(comment) > 0:
                comments.append(comment)
                comment = ''
            comment += ' '.join(df_revision[df_revision.columns[3]][i].split(' ')[1:])

        if df_comment['full comment'][i] == True and df_null[df_null.columns[2]][i] == True:
            comment += df_revision[df_revision.columns[3]][i]

        if df_comment['full comment'][i] == True and df_null[df_null.columns[2]][i] == False:
            if len(comment) > 0:
                comments.append(comment)
                comment = ''
            comments.append(df_revision[df_revision.columns[3]][i])

        if df_comment['continued comment'][i] == True:
            comment += df_revision[df_revision.columns[3]][i]

    if len(comment) > 0:
        comments.append(comment)        


    df_output = pd.DataFrame(
        {'unit': unit,
         'station': station,
         'line': line,
         'availability': availability,
         'comments' : comments
        })
# Out:
# /Users/robblatt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:70: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-1f5180e7fb03> in <module>
#     119          'line': line,
#     120          'availability': availability,
# --> 121          'comments' : comments
#     122         })
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df_output
# Out:
#     unit              station     line availability  \
# 0  ES101               125 St        1       73.83%
# 1  ES204  Grand Central‐42 St        7       71.47%
# 2  ES285                72 St        Q       72.02%
# 3  ES325            West 4 St  ABCDEFM       74.49%
# 4  ES326            West 4 St  ABCDEFM       81.96%
# 5  ES627   34 St‐Hudson Yards        7       84.55%
# 6  ES629   34 St‐Hudson Yards        7       83.73%
#
#                                             comments
# 0  This escalator was out of service multiple tim...
# 1  This escalator was out of service from 6/6/17 ...
# 2  This escalator was out of service  from 4/15/1...
# 3  This escalator was out of service from 4/29/17...
# 4  This escalator was out of service from 4/8/17 ...
# 5  This escalator was out of service from 4/13/17...
# 6  The escalator was out of service from 6/2/17 t...

# %%
station
# Out:
# ['',
#  'West Farms Sq‐E Tremont Av',
#  'Pelham Bay Park',
#  'Smith 9 St',
#  'High St',
#  'Myrtle‐Wyckoff Avs',
#  'West 8 St‐NY Aquarium',
#  'Brighton Beach',
#  'Broadway Junction']

# %%
len(comments)
# Out:
# 8
